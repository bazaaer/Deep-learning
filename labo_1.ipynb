# %%
# Installeer TensorFlow in de terminal van VS Code met het commando: pip install tensorflow
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import numpy as np

# Dummy-data genereren (vervang dit door je eigen data)
from sklearn import datasets
iris = datasets.load_iris()

log_dir = "./logs/labo1"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

X=iris.data
y=iris.target

X_train,X_test,y_train,y_test=train_test_split(X,y)
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


# Model bouwen
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(4,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3, activation='sigmoid')
])

# Model compileren
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


# Model samenvatting weergeven
model.summary()
# Model trainen
model.fit(X_train, y_train, epochs=50, callbacks=[tensorboard_callback])

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)



# Model evalueren
print("accuracy_score: " + str(accuracy_score(y_test, y_pred)))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               640
#
#  dense_13 (Dense)            (None, 128)               16512
#
#  dense_14 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 17539 (68.51 KB)
# Trainable params: 17539 (68.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 4/4 [==============================] - 2s 30ms/step - loss: 1.0024 - accuracy: 0.5536
# Epoch 2/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.8315 - accuracy: 0.7143
# Epoch 3/50
# 4/4 [==============================] - 0s 33ms/step - loss: 0.7014 - accuracy: 0.8214
# Epoch 4/50
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5980 - accuracy: 0.8304
# Epoch 5/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.5149 - accuracy: 0.8304
# Epoch 6/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4488 - accuracy: 0.8393
# Epoch 7/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3993 - accuracy: 0.8482
# Epoch 8/50
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3647 - accuracy: 0.8571
# Epoch 9/50
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3351 - accuracy: 0.8571
# Epoch 10/50
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3131 - accuracy: 0.8661
# Epoch 11/50
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2954 - accuracy: 0.8661
# Epoch 12/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2780 - accuracy: 0.8661
# Epoch 13/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2637 - accuracy: 0.8661
# Epoch 14/50
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2480 - accuracy: 0.8750
# Epoch 15/50
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2344 - accuracy: 0.8839
# Epoch 16/50
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2221 - accuracy: 0.9018
# Epoch 17/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2097 - accuracy: 0.9107
# Epoch 18/50
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1984 - accuracy: 0.9375
# Epoch 19/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1858 - accuracy: 0.9375
# Epoch 20/50
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1754 - accuracy: 0.9464
# Epoch 21/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1653 - accuracy: 0.9554
# Epoch 22/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1564 - accuracy: 0.9643
# Epoch 23/50
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1456 - accuracy: 0.9643
# Epoch 24/50
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1361 - accuracy: 0.9643
# Epoch 25/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1273 - accuracy: 0.9732
# Epoch 26/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1196 - accuracy: 0.9732
# Epoch 27/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1104 - accuracy: 0.9732
# Epoch 28/50
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1032 - accuracy: 0.9732
# Epoch 29/50
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0972 - accuracy: 0.9732
# Epoch 30/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0921 - accuracy: 0.9732
# Epoch 31/50
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0863 - accuracy: 0.9732
# Epoch 32/50
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0787 - accuracy: 0.9821
# Epoch 33/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0736 - accuracy: 0.9821
# Epoch 34/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0702 - accuracy: 0.9821
# Epoch 35/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0644 - accuracy: 0.9821
# Epoch 36/50
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0624 - accuracy: 0.9911
# Epoch 37/50
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0610 - accuracy: 0.9821
# Epoch 38/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0548 - accuracy: 0.9911
# Epoch 39/50
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0532 - accuracy: 0.9911
# Epoch 40/50
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0508 - accuracy: 0.9821
# Epoch 41/50
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0477 - accuracy: 0.9911
# Epoch 42/50
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0447 - accuracy: 0.9911
# Epoch 43/50
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0431 - accuracy: 0.9911
# Epoch 44/50
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0352 - accuracy: 0.9911
# Epoch 49/50
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0323 - accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000203B49BC0E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step
# accuracy_score: 0.9210526315789473

# %%
y_pred
# Out:
# array([0, 2, 2, 0, 1, 0, 1, 0, 1, 0, 2, 1, 2, 0, 0, 2, 2, 2, 1, 2, 1, 0,
#        1, 2, 2, 0, 1, 1, 2, 2, 2, 2, 0, 1, 1, 2, 0, 0], dtype=int64)
